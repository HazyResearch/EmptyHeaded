# %%
import emptyheaded

# %%
emptyheaded.query("result(a) :- takesCourse(a,b=0),type(a,c=1).")
# Out:
# NUMBER OF FHW RELATIONS:2
# {
#   "query_type":"join",
#   "relations":[{
#     "name":"takesCourse",
#     "ordering":[0,1],
#     "annotation":"void*"
#   },{
#     "name":"type",
#     "ordering":[0,1],
#     "annotation":"void*"
#   }],
#   "output":{
#     "name":"result",
#     "ordering":[0],
#     "annotation":"void*"
#   },
#   "ghd":[{
#     "name":"result",
#     "attributes":["a"],
#     "annotation":"void*",
#     "relations":[{
#       "name":"takesCourse",
#       "ordering":[0,1],
#       "attributes":[["a","b"]],
#       "annotation":"void*"
#     },{
#       "name":"bag_1_0",
#       "ordering":[0],
#       "attributes":[["a"]],
#       "annotation":"void*"
#     }],
#     "nprr":[{
#       "name":"a",
#       "accessors":[{
#         "name":"takesCourse",
#         "attrs":["a","b"],
#         "annotated":false
#       },{
#         "name":"bag_1_0",
#         "attrs":["a"],
#         "annotated":false
#       }],
#       "materialize":true,
# ...

# %%
emptyheaded.query("result(a,b,c) :- memberOf(a,b),subOrganizationOf(b,c),undegraduateDegreeFrom(a,c),type(a,x=1),type(b,y=2),type(c,z=3).")
# Out:
# NUMBER OF FHW RELATIONS:6
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "subOrganizationOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "undegraduateDegreeFrom",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "memberOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       0,
#       1,
#       2
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
#           "nextMaterialized" : "None",
#           "name" : "a",
#           "accessors" : [
#             {
# ...

# %%
emptyheaded.query("result(a,b,c,d) :- worksFor(a,e=1),name(a,b),emailAddress(a,d),telephone(a,c),type(a,f=2).")
# Out:
# NUMBER OF FHW RELATIONS:5
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "worksFor",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "emailAddress",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "telephone",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "name",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       0,
#       1,
#       2,
#       3
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
# ...

# %%
emptyheaded.query("result(a) :- type(a,b=1).")
# Out:
# NUMBER OF FHW RELATIONS:1
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       0
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
#           "nextMaterialized" : "None",
#           "name" : "a",
#           "accessors" : [
#             {
#               "name" : "type",
#               "attrs" : [
#                 "a",
#                 "b"
#               ],
#               "annotated" : false
#             }
#           ],
#           "annotation" : "None",
#           "selection" : false,
#           "aggregation" : "None",
#           "materialize" : true,
#           "prevMaterialized" : "None"
#         },
#         {
#           "nextMaterialized" : "None",
#           "name" : "b",
# ...

# %%
emptyheaded.query("result(a,b) :- teacherOf(c=1,b),takesCourse(a,b),type(b,d=2),type(a,e=3).")
# Out:
# NUMBER OF FHW RELATIONS:4
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "teacherOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "takesCourse",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       1,
#       0
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
#           "nextMaterialized" : "None",
#           "name" : "b",
#           "accessors" : [
#             {
#               "name" : "teacherOf",
#               "attrs" : [
#                 "c",
#                 "b"
#               ],
#               "annotated" : false
#             },
# ...

# %%
emptyheaded.query("result(a,b,c) :- memberOf(a,b),emailAddress(a,c),type(a,d=1),subOrganizationOf(b,e=2),type(b,f=3).")
# Out:
# NUMBER OF FHW RELATIONS:5
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "memberOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "subOrganizationOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "emailAddress",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       0,
#       1,
#       2
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
#           "nextMaterialized" : "b",
#           "name" : "a",
#           "accessors" : [
#             {
# ...

# %%
emptyheaded.query("result(a,b) :- worksFor(a,b),type(a,c=1),subOrganizationOf(b,d=2),type(b,e=3).")
# Out:
# NUMBER OF FHW RELATIONS:4
# {
#   "query_type" : "join",
#   "relations" : [
#     {
#       "name" : "worksFor",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "type",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     },
#     {
#       "name" : "subOrganizationOf",
#       "ordering" : [
#         0,
#         1
#       ],
#       "annotation" : "void*"
#     }
#   ],
#   "output" : {
#     "name" : "result",
#     "ordering" : [
#       0,
#       1
#     ],
#     "annotation" : "void*"
#   },
#   "ghd" : [
#     {
#       "name" : "result",
#       "nprr" : [
#         {
#           "nextMaterialized" : "b",
#           "name" : "a",
#           "accessors" : [
#             {
#               "name" : "worksFor",
#               "attrs" : [
#                 "a",
#                 "b"
#               ],
#               "annotated" : false
#             },
# ...
