# %%
import emptyheaded
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-38039cd2d750> in <module>()
# ----> 1 import emptyheaded
#
# ImportError: No module named emptyheaded
