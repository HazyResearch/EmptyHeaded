# %% [markdown]
# <img src="../graph/figs/eh_logo.png" style="width: 200px;">
#
# # EmptyHeaded RDF Tutorial
#
# This is a brief example of how to run EmptyHeaded on RDF data.
# We first provide a brief system overview then discuss how to run a sample query from the [Lehigh University Benchmark (LUBM)](http://swat.cse.lehigh.edu/projects/lubm/) in EmptyHeaded.
#
# This example assumes that you have resolved all dependencies listed on our [GitHub](https://github.com/craberger/EmptyHeaded) page and were able to run `setup.sh` successfully.

# %% [markdown]
# ## Loading the database
#
# First lets load a database to run the RDF query over.

# %%
import emptyheaded
emptyheaded.createDB("$EMPTYHEADED_HOME/examples/rdf/data/lubm1/config.json")
emptyheaded.loadDB("$EMPTYHEADED_HOME/examples/rdf/data/lubm1/db")
# Out:
# Created database with the following relations:
# 	takesCourse(subject:std::string,subject:std::string)
# 	memberOf(subject:std::string,subject:std::string)
# 	subOrganizationOf(subject:std::string,subject:std::string)
# 	undegraduateDegreeFrom(subject:std::string,subject:std::string)
# 	rdftype(subject:std::string,types:std::string)
# 	worksFor(subject:std::string,subject:std::string)
# 	name(subject:std::string,name:std::string)
# 	emailAddress(subject:std::string,email:std::string)
# 	telephone(subject:std::string,telephone:std::string)
# 	teacherOf(subject:std::string,subject:std::string)

# %% [markdown]
# ## Constructing the query
#
# Now that the database is loaded, let's run the first query from the LUBM benchmark.

# %%
emptyheaded.query("lubm1(a) :- takesCourse(a,b='http://www.Department0.University0.edu/GraduateCourse0'),rdftype(a,c='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#GraduateStudent').")

# %% [markdown]
# ## Inspecting the result
#
# As before the data comes back in the form of a Pandas dataframe.

# %%
emptyheaded.fetchData("lubm1")
# Out:
#                                                            0
# 0  http://www.Department0.University0.edu/GraduateStudent101
# 1  http://www.Department0.University0.edu/GraduateStudent124
# 2  http://www.Department0.University0.edu/GraduateStudent142
# 3   http://www.Department0.University0.edu/GraduateStudent44

# %% [markdown]
# ## Other queries
#
# We include here two other LUBM queries for you to try. Note the first of the two (which should result in 0 rows) includes a triangle query. (Recall that we ran a triangle query in the Getting Started tutorial.) The edges are the undergraduateDegreeFrom, memberOf, and subOrganizationOf relations.

# %%
emptyheaded.query("lubm2(a,b,c) :- memberOf(a,b),subOrganizationOf(b,c),undegraduateDegreeFrom(a,c),rdftype(a,x='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#GraduateStudent'),rdftype(b,y='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#Department'),rdftype(c,z='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#University').")
emptyheaded.fetchData("lubm2")
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
emptyheaded.query("lubm12(a,b) :- worksFor(a,b),rdftype(a,c='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#FullProfessor'),subOrganizationOf(b,d='http://www.University0.edu'),rdftype(b,e='http://www.lehigh.edu/~zhp2/2004/0401/univ-bench.owl#Department').")
emptyheaded.fetchData("lubm12")
# Out:
#                                                           0  \
# 0     http://www.Department0.University0.edu/FullProfessor0
# 1     http://www.Department0.University0.edu/FullProfessor1
# 2     http://www.Department0.University0.edu/FullProfessor2
# 3     http://www.Department0.University0.edu/FullProfessor3
# 4     http://www.Department0.University0.edu/FullProfessor4
# 5     http://www.Department0.University0.edu/FullProfessor5
# 6     http://www.Department0.University0.edu/FullProfessor6
# 7     http://www.Department0.University0.edu/FullProfessor7
# 8     http://www.Department0.University0.edu/FullProfessor8
# 9     http://www.Department0.University0.edu/FullProfessor9
# 10    http://www.Department1.University0.edu/FullProfessor0
# 11    http://www.Department1.University0.edu/FullProfessor1
# 12    http://www.Department1.University0.edu/FullProfessor2
# 13    http://www.Department1.University0.edu/FullProfessor3
# 14    http://www.Department1.University0.edu/FullProfessor4
# 15    http://www.Department1.University0.edu/FullProfessor5
# 16    http://www.Department1.University0.edu/FullProfessor6
# 17    http://www.Department1.University0.edu/FullProfessor7
# 18    http://www.Department1.University0.edu/FullProfessor8
# 19    http://www.Department1.University0.edu/FullProfessor9
# 20   http://www.Department10.University0.edu/FullProfessor0
# 21   http://www.Department10.University0.edu/FullProfessor1
# 22   http://www.Department10.University0.edu/FullProfessor2
# 23   http://www.Department10.University0.edu/FullProfessor3
# 24   http://www.Department10.University0.edu/FullProfessor4
# 25   http://www.Department10.University0.edu/FullProfessor5
# 26   http://www.Department10.University0.edu/FullProfessor6
# 27   http://www.Department11.University0.edu/FullProfessor0
# 28   http://www.Department11.University0.edu/FullProfessor1
# 29   http://www.Department11.University0.edu/FullProfessor2
# ..                                                      ...
# 95    http://www.Department6.University0.edu/FullProfessor3
# 96    http://www.Department6.University0.edu/FullProfessor4
# 97    http://www.Department6.University0.edu/FullProfessor5
# 98    http://www.Department6.University0.edu/FullProfessor6
# 99    http://www.Department6.University0.edu/FullProfessor7
# 100   http://www.Department6.University0.edu/FullProfessor8
# 101   http://www.Department6.University0.edu/FullProfessor9
# 102   http://www.Department7.University0.edu/FullProfessor0
# 103   http://www.Department7.University0.edu/FullProfessor1
# 104   http://www.Department7.University0.edu/FullProfessor2
# 105   http://www.Department7.University0.edu/FullProfessor3
# 106   http://www.Department7.University0.edu/FullProfessor4
# 107   http://www.Department7.University0.edu/FullProfessor5
# 108   http://www.Department7.University0.edu/FullProfessor6
# 109   http://www.Department8.University0.edu/FullProfessor0
# 110   http://www.Department8.University0.edu/FullProfessor1
# 111   http://www.Department8.University0.edu/FullProfessor2
# 112   http://www.Department8.University0.edu/FullProfessor3
# 113   http://www.Department8.University0.edu/FullProfessor4
